# %% [markdown]
# # Multiple rock types tracking
#
#
# <div class="alert alert-block alert-danger">The option below has not really been tested and the performance of the code when using it will be really slow...</div>
#
#
#
# ***
#
# <img src="images/rocktrack.png" alt="geometry" width="900" height="500"/>
#
# _Above image shows the proportion of a specific rock (rock 1 ranging between 0 and 1) after 100,000 years. The initial model is composed of stratigraphic layers. A top one made only of 250 m of rock 0 and a bottom one made of rock 0 on half of the domain and of rock 1 on the other half. As the model starts, the top layer is first eroded and as the erosion progesses the second layer starts to be exposed and rock 1 starts to be deposited in the marine environment._
#
#
# <img src="images/rock1.png" alt="geometry" width="500" height="500"/>
#
# _Proportion of rock 1 in the sedimentary record which is higher than 40% (using Paraview)._
#
# ***
#
# The approach consists in assigning multiple stratigraphic layers initially in the model and for each **node a specific rock type**. Multiple rock types can be defined on a single layer and there are no restriction on the number of types though the run time will become slower and slower has you increase it!
#
# > One restriction is that on a single layer you will only be able to define for each point a single rock type.
#
# Basically you cannot have 50% of rock 1 and 50% of rock 2 on the one point of a single layer. But you can create 2 layers on top of each others one with only rock 1 and the second with rock 2.
#
# **Each layer has to be defined for all the nodes part of the computational domain but can have 0 thickness.**
#
# To use the option you will need to add the following `XmL` element in the input file.
#
# ```xml
#
#     <!-- Erodibility structure
#          This option allows you to specify different erodibility values either on the surface
#          or within a number of initial stratigraphic layers. -->
#     <erocoeffs>
#         <!-- Active layer thickness [m]-->
#         <actlay>5.</actlay>
#         <!-- Stratal layer interval [a] -->
#         <laytime>5000.</laytime>
#         <!-- Number of rock types to track. -->
#         <rocktype>2</rocktype>
#         <!-- Definition of erodibility values for each rock types -->
#         <rockero>
#             <!-- Erodibility coefficient for rock type 1 -->
#             <erorock>1.e-5</erorock>
#         </rockero>
#         <rockero>
#             <!-- Erodibility coefficient for rock type 2 -->
#             <erorock>3.e-5</erorock>
#         </rockero>
#
#         <!-- Number of erosion layers. -->
#         <erolayers>2</erolayers>
#         <!-- The layering is defined from top to bottom, with a file containing the
#              following properties for each points of the regular grid (DEM):
#               - 1st column the thickness of the considered layer
#               - 2nd column the rock type ID (an integer) -->
#         <!-- Constant erodibility and layer thickness -->
#         <erolay>
#             <!-- Uniform erodibility value for the considered layer. -->
#             <laymap>data/thlay0.csv</laymap>
#         </erolay>
#         <erolay>
#             <!-- Uniform erodibility value for the considered layer. -->
#             <laymap>data/thlay1.csv</laymap>
#         </erolay>
#     </erocoeffs>
# ```
#
# As seen above, we set 2 rocktypes, each rock is defined with a specific erodibility coefficient. Once eroded from their respective stratigraphic layer, all sediments will have an erodibility coefficient defined in the `<spl_law>` element of the `XmL` input file.
#
#
# I guess, in your case, if the idea is to track a rock from a particular catchment you can set the erodibility coefficient to the same values everywhere...
#
# An example on how to create these stratigraphic layers is provided in the second notebook part of this folder:
# + `buildLayer.ipynb`

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
import numpy as np
from scripts import stratiMesh as strati
from pyBadlands.model import Model as badlandsModel

# %%
modelA = 31          # Number of the first model to be run
modelB = 40          # Number of the last model to be run
models = np.arange(modelA, modelB + 1)       # Create array of model numbers

runTime = 55000            # Time to run model to in years

# %%
for i in models:
    # Initialise model
    model = badlandsModel()

    # Define the XmL input file
    model.load_xml('Pur' + str(i).zfill(3) + '.xml')
    
    # Run the model
    model.run_to_time(runTime)
    
    print "        Model Pur" + str(i).zfill(3) + " run"
    
    # Initialise the mesh function
    mesh = strati.stratiMesh(folder='Pur' + str(i).zfill(3), xdmfName = 'stratal_series', ncpus=1, layperstep=1, dispTime=1000.)
    
    # Create the stratigraphic mesh for each of the stratigraphic layers
    mesh.outputSteps(startTime=0.,endTime=runTime)
    
    print "        Model Pur" + str(i).zfill(3) + " stratal_series created"
    
print "Done"
# Out:
#    - Writing outputs (1.26 seconds; tNow = 0.0)
#    - Write sediment mesh output 13.820199
#    - Writing outputs (0.93 seconds; tNow = 1000.0)
#    - Write sediment mesh output 13.774502
# tNow = 1961.0 (step took 1.10 seconds)
#    - Writing outputs (0.93 seconds; tNow = 2000.0)
#    - Write sediment mesh output 14.001449
# tNow = 3000.0 (step took 1.01 seconds)
#    - Writing outputs (0.94 seconds; tNow = 3000.0)
#    - Write sediment mesh output 14.14849
# tNow = 3303.0 (step took 1.07 seconds)
#    - Writing outputs (0.92 seconds; tNow = 4000.0)
#    - Write sediment mesh output 14.057729
# tNow = 4678.0 (step took 1.04 seconds)
#    - Writing outputs (1.00 seconds; tNow = 5000.0)
#    - Write sediment mesh output 14.72745
# tNow = 5660.0 (step took 1.04 seconds)
#    - Writing outputs (0.95 seconds; tNow = 6000.0)
#    - Write sediment mesh output 14.426469
# tNow = 6339.0 (step took 20.68 seconds)
#    - Writing outputs (0.92 seconds; tNow = 7000.0)
#    - Write sediment mesh output 14.404769
# tNow = 7339.0 (step took 21.50 seconds)
#    - Writing outputs (0.95 seconds; tNow = 8000.0)
#    - Write sediment mesh output 15.231442
# tNow = 8267.0 (step took 22.96 seconds)
#    - Writing outputs (0.96 seconds; tNow = 9000.0)
#    - Write sediment mesh output 14.722055
# tNow = 9339.0 (step took 22.64 seconds)
#    - Writing outputs (0.97 seconds; tNow = 10000.0)
#    - Write sediment mesh output 14.762446
# tNow = 10339.0 (step took 22.97 seconds)
#    - Writing outputs (0.93 seconds; tNow = 11000.0)
#    - Write sediment mesh output 14.659754
# tNow = 11339.0 (step took 23.60 seconds)
#    - Writing outputs (0.94 seconds; tNow = 12000.0)
#    - Write sediment mesh output 14.672251
# tNow = 12339.0 (step took 23.88 seconds)
#    - Writing outputs (0.93 seconds; tNow = 13000.0)
#    - Write sediment mesh output 14.830334
# tNow = 13272.0 (step took 24.63 seconds)
#    - Writing outputs (0.94 seconds; tNow = 14000.0)
#    - Write sediment mesh output 14.873588
# tNow = 14339.0 (step took 25.11 seconds)
#    - Writing outputs (0.92 seconds; tNow = 15000.0)
#    - Write sediment mesh output 14.883675
# tNow = 15338.0 (step took 25.36 seconds)
#    - Writing outputs (0.91 seconds; tNow = 16000.0)
#    - Write sediment mesh output 14.966578
# tNow = 16329.0 (step took 25.82 seconds)
#    - Writing outputs (0.92 seconds; tNow = 17000.0)
#    - Write sediment mesh output 15.120536
# tNow = 17339.0 (step took 26.93 seconds)
# tNow = 18000.0 (step took 1.71 seconds)
#    - Writing outputs (0.92 seconds; tNow = 18000.0)
#    - Write sediment mesh output 15.1268
# tNow = 18263.0 (step took 27.52 seconds)
# tNow = 19000.0 (step took 1.81 seconds)
#    - Writing outputs (0.92 seconds; tNow = 19000.0)
#    - Write sediment mesh output 15.281798
# tNow = 19248.0 (step took 28.17 seconds)
# tNow = 19966.0 (step took 1.87 seconds)
#    - Writing outputs (0.92 seconds; tNow = 20000.0)
#    - Write sediment mesh output 15.158484
# tNow = 20278.0 (step took 28.76 seconds)
# tNow = 20967.0 (step took 1.90 seconds)
#    - Writing outputs (0.92 seconds; tNow = 21000.0)
#    - Write sediment mesh output 15.869768
# tNow = 21212.0 (step took 30.08 seconds)
# tNow = 21951.0 (step took 1.98 seconds)
#    - Writing outputs (0.97 seconds; tNow = 22000.0)
#    - Write sediment mesh output 16.003754
# tNow = 22271.0 (step took 30.95 seconds)
# tNow = 22906.0 (step took 2.06 seconds)
#    - Writing outputs (0.94 seconds; tNow = 23000.0)
#    - Write sediment mesh output 15.85211
# tNow = 23234.0 (step took 30.74 seconds)
# tNow = 23909.0 (step took 2.11 seconds)
#    - Writing outputs (0.94 seconds; tNow = 24000.0)
#    - Write sediment mesh output 15.832134
# tNow = 24205.0 (step took 31.55 seconds)
# tNow = 24936.0 (step took 2.18 seconds)
#    - Writing outputs (0.92 seconds; tNow = 25000.0)
#    - Write sediment mesh output 15.950992
# tNow = 25226.0 (step took 32.12 seconds)
# tNow = 25994.0 (step took 2.37 seconds)
#    - Writing outputs (0.97 seconds; tNow = 26000.0)
#    - Write sediment mesh output 16.230871
# tNow = 26245.0 (step took 33.70 seconds)
# tNow = 27000.0 (step took 2.31 seconds)
#    - Writing outputs (0.95 seconds; tNow = 27000.0)
#    - Write sediment mesh output 16.263732
# tNow = 27248.0 (step took 33.72 seconds)
# tNow = 28000.0 (step took 2.45 seconds)
#    - Writing outputs (0.95 seconds; tNow = 28000.0)
#    - Write sediment mesh output 16.607026
# tNow = 28226.0 (step took 34.77 seconds)
# tNow = 29000.0 (step took 2.42 seconds)
#    - Writing outputs (0.94 seconds; tNow = 29000.0)
#    - Write sediment mesh output 16.680033
# tNow = 29183.0 (step took 35.07 seconds)
# tNow = 29935.0 (step took 2.45 seconds)
#    - Writing outputs (0.95 seconds; tNow = 30000.0)
#    - Write sediment mesh output 16.66289
# tNow = 30329.0 (step took 36.36 seconds)
# tNow = 30910.0 (step took 2.53 seconds)
#    - Writing outputs (0.94 seconds; tNow = 31000.0)
#    - Write sediment mesh output 16.490195
# tNow = 31338.0 (step took 36.05 seconds)
# tNow = 31787.0 (step took 2.93 seconds)
#    - Writing outputs (0.94 seconds; tNow = 32000.0)
#    - Write sediment mesh output 16.79585
# tNow = 32273.0 (step took 36.82 seconds)
# tNow = 32909.0 (step took 2.73 seconds)
#    - Writing outputs (0.94 seconds; tNow = 33000.0)
#    - Write sediment mesh output 16.778868
# tNow = 33338.0 (step took 35.09 seconds)
# tNow = 33771.0 (step took 2.66 seconds)
# tNow = 34000.0 (step took 2.63 seconds)
#    - Writing outputs (0.95 seconds; tNow = 34000.0)
#    - Write sediment mesh output 16.666716
# tNow = 34205.0 (step took 35.05 seconds)
# tNow = 34749.0 (step took 2.83 seconds)
#    - Writing outputs (0.95 seconds; tNow = 35000.0)
#    - Write sediment mesh output 17.064992
# tNow = 35204.0 (step took 36.83 seconds)
# tNow = 35708.0 (step took 2.93 seconds)
#    - Writing outputs (0.95 seconds; tNow = 36000.0)
#    - Write sediment mesh output 17.036869
# tNow = 36312.0 (step took 36.48 seconds)
# tNow = 36753.0 (step took 2.90 seconds)
# tNow = 37000.0 (step took 2.86 seconds)
#    - Writing outputs (0.93 seconds; tNow = 37000.0)
#    - Write sediment mesh output 16.886635
# tNow = 37231.0 (step took 37.01 seconds)
# tNow = 37741.0 (step took 2.92 seconds)
#    - Writing outputs (0.94 seconds; tNow = 38000.0)
#    - Write sediment mesh output 17.131409
# tNow = 38237.0 (step took 37.57 seconds)
# tNow = 38762.0 (step took 3.13 seconds)
#    - Writing outputs (0.96 seconds; tNow = 39000.0)
#    - Write sediment mesh output 17.046446
# tNow = 39338.0 (step took 38.26 seconds)
# tNow = 39931.0 (step took 3.16 seconds)
#    - Writing outputs (0.93 seconds; tNow = 40000.0)
#    - Write sediment mesh output 17.211149
# tNow = 40186.0 (step took 38.82 seconds)
# tNow = 40673.0 (step took 3.41 seconds)
# tNow = 41000.0 (step took 3.34 seconds)
#    - Writing outputs (0.94 seconds; tNow = 41000.0)
#    - Write sediment mesh output 17.305818
# tNow = 41338.0 (step took 39.24 seconds)
# tNow = 41896.0 (step took 3.40 seconds)
#    - Writing outputs (0.99 seconds; tNow = 42000.0)
#    - Write sediment mesh output 17.558315
# tNow = 42223.0 (step took 39.53 seconds)
# tNow = 42752.0 (step took 3.36 seconds)
# tNow = 43000.0 (step took 3.30 seconds)
#    - Writing outputs (0.93 seconds; tNow = 43000.0)
#    - Write sediment mesh output 17.265042
# tNow = 43268.0 (step took 40.05 seconds)
# tNow = 43714.0 (step took 3.59 seconds)
# tNow = 44000.0 (step took 3.50 seconds)
#    - Writing outputs (0.93 seconds; tNow = 44000.0)
#    - Write sediment mesh output 17.449311
# tNow = 44273.0 (step took 40.39 seconds)
# tNow = 44734.0 (step took 3.89 seconds)
# tNow = 45000.0 (step took 3.73 seconds)
#    - Writing outputs (0.96 seconds; tNow = 45000.0)
#    - Write sediment mesh output 18.415473
# tNow = 45242.0 (step took 42.30 seconds)
# tNow = 45796.0 (step took 3.52 seconds)
#    - Writing outputs (0.97 seconds; tNow = 46000.0)
#    - Write sediment mesh output 17.776245
# tNow = 46272.0 (step took 41.61 seconds)
# tNow = 46757.0 (step took 3.50 seconds)
# tNow = 47000.0 (step took 3.42 seconds)
#    - Writing outputs (0.93 seconds; tNow = 47000.0)
#    - Write sediment mesh output 17.437803
# tNow = 47338.0 (step took 42.29 seconds)
# tNow = 48000.0 (step took 4.11 seconds)
#    - Writing outputs (0.95 seconds; tNow = 48000.0)
#    - Write sediment mesh output 18.466413
# tNow = 48248.0 (step took 44.02 seconds)
# tNow = 48930.0 (step took 4.26 seconds)
#    - Writing outputs (0.96 seconds; tNow = 49000.0)
#    - Write sediment mesh output 18.30505
# tNow = 49193.0 (step took 44.02 seconds)
# tNow = 49691.0 (step took 3.99 seconds)
#    - Writing outputs (0.95 seconds; tNow = 50000.0)
#    - Write sediment mesh output 18.097753
# tNow = 50208.0 (step took 44.04 seconds)
# tNow = 50817.0 (step took 4.30 seconds)
#    - Writing outputs (0.94 seconds; tNow = 51000.0)
#    - Write sediment mesh output 18.820524
# tNow = 51302.0 (step took 46.14 seconds)
# tNow = 52000.0 (step took 4.67 seconds)
#    - Writing outputs (0.96 seconds; tNow = 52000.0)
#    - Write sediment mesh output 18.710511
# tNow = 52259.0 (step took 45.79 seconds)
# tNow = 52830.0 (step took 4.35 seconds)
#    - Writing outputs (0.93 seconds; tNow = 53000.0)
#    - Write sediment mesh output 18.786798
# tNow = 53301.0 (step took 46.52 seconds)
# tNow = 53993.0 (step took 4.58 seconds)
#    - Writing outputs (0.94 seconds; tNow = 54000.0)
#    - Write sediment mesh output 18.937245
# tNow = 54254.0 (step took 47.37 seconds)
# tNow = 54915.0 (step took 4.89 seconds)
# tNow = 55000.0 (4.95 seconds)
#    - Writing outputs (0.97 seconds; tNow = 55000.0)
#         Model Pur031 run
# Process layers at time [in years]:  0.0
# Process layers at time [in years]:  1000.0
# Process layers at time [in years]:  2000.0
# Process layers at time [in years]:  3000.0
# Process layers at time [in years]:  4000.0
# Process layers at time [in years]:  5000.0
# Process layers at time [in years]:  6000.0
# Process layers at time [in years]:  7000.0
# Process layers at time [in years]:  8000.0
# Process layers at time [in years]:  9000.0
# Process layers at time [in years]:  10000.0
# Process layers at time [in years]:  11000.0
# Process layers at time [in years]:  12000.0
# Process layers at time [in years]:  13000.0
# Process layers at time [in years]:  14000.0
# Process layers at time [in years]:  15000.0
# Process layers at time [in years]:  16000.0
# Process layers at time [in years]:  17000.0
# Process layers at time [in years]:  18000.0
# Process layers at time [in years]:  19000.0
# Process layers at time [in years]:  20000.0
# Process layers at time [in years]:  21000.0
# Process layers at time [in years]:  22000.0
# Process layers at time [in years]:  23000.0
# Process layers at time [in years]:  24000.0
# Process layers at time [in years]:  25000.0
# Process layers at time [in years]:  26000.0
# Process layers at time [in years]:  27000.0
# Process layers at time [in years]:  28000.0
# Process layers at time [in years]:  29000.0
# Process layers at time [in years]:  30000.0
# Process layers at time [in years]:  31000.0
# Process layers at time [in years]:  32000.0
# Process layers at time [in years]:  33000.0
# Process layers at time [in years]:  34000.0
# Process layers at time [in years]:  35000.0
# Process layers at time [in years]:  36000.0
# Process layers at time [in years]:  37000.0
# Process layers at time [in years]:  38000.0
# Process layers at time [in years]:  39000.0
# Process layers at time [in years]:  40000.0
# Process layers at time [in years]:  41000.0
# Process layers at time [in years]:  42000.0
# Process layers at time [in years]:  43000.0
# Process layers at time [in years]:  44000.0
# Process layers at time [in years]:  45000.0
# Process layers at time [in years]:  46000.0
# Process layers at time [in years]:  47000.0
# Process layers at time [in years]:  48000.0
# Process layers at time [in years]:  49000.0
# Process layers at time [in years]:  50000.0
# Process layers at time [in years]:  51000.0
# Process layers at time [in years]:  52000.0
# Process layers at time [in years]:  53000.0
# Process layers at time [in years]:  54000.0
# Process layers at time [in years]:  55000.0
#         Model Pur031 stratal_series created
#    - Writing outputs (1.25 seconds; tNow = 0.0)
#    - Write sediment mesh output 14.311979
#    - Writing outputs (0.93 seconds; tNow = 1000.0)
#    - Write sediment mesh output 14.096624
# tNow = 1961.0 (step took 1.10 seconds)
#    - Writing outputs (0.98 seconds; tNow = 2000.0)
#    - Write sediment mesh output 13.945373
# tNow = 3000.0 (step took 1.02 seconds)
#    - Writing outputs (0.94 seconds; tNow = 3000.0)
#    - Write sediment mesh output 14.08438
# tNow = 3171.0 (step took 1.11 seconds)
#    - Writing outputs (0.93 seconds; tNow = 4000.0)
#    - Write sediment mesh output 14.192391
# tNow = 4660.0 (step took 1.00 seconds)
#    - Writing outputs (0.93 seconds; tNow = 5000.0)
#    - Write sediment mesh output 14.518933
# tNow = 5678.0 (step took 1.10 seconds)
#    - Writing outputs (0.96 seconds; tNow = 6000.0)
#    - Write sediment mesh output 14.739345
# tNow = 6335.0 (step took 21.16 seconds)
#    - Writing outputs (0.97 seconds; tNow = 7000.0)
#    - Write sediment mesh output 14.902412
# tNow = 7247.0 (step took 21.89 seconds)
#    - Writing outputs (0.95 seconds; tNow = 8000.0)
#    - Write sediment mesh output 14.713496
# tNow = 8260.0 (step took 22.17 seconds)
#    - Writing outputs (0.94 seconds; tNow = 9000.0)
#    - Write sediment mesh output 14.838724
# tNow = 9339.0 (step took 22.74 seconds)
#    - Writing outputs (0.95 seconds; tNow = 10000.0)
#    - Write sediment mesh output 15.074067
# tNow = 10339.0 (step took 23.42 seconds)
#    - Writing outputs (0.94 seconds; tNow = 11000.0)
#    - Write sediment mesh output 15.004645
# tNow = 11222.0 (step took 23.74 seconds)
#    - Writing outputs (0.96 seconds; tNow = 12000.0)
#    - Write sediment mesh output 15.100587
# tNow = 12226.0 (step took 24.46 seconds)
# tNow = 13000.0 (step took 1.51 seconds)
#    - Writing outputs (0.96 seconds; tNow = 13000.0)
#    - Write sediment mesh output 15.216785
# tNow = 13339.0 (step took 25.08 seconds)
#    - Writing outputs (0.98 seconds; tNow = 14000.0)
#    - Write sediment mesh output 15.080781
# tNow = 14300.0 (step took 25.31 seconds)
#    - Writing outputs (0.94 seconds; tNow = 15000.0)
#    - Write sediment mesh output 15.169715
# tNow = 15225.0 (step took 25.82 seconds)
# tNow = 15894.0 (step took 1.70 seconds)
#    - Writing outputs (1.05 seconds; tNow = 16000.0)
#    - Write sediment mesh output 16.064837
# tNow = 16245.0 (step took 27.37 seconds)
# tNow = 17000.0 (step took 1.79 seconds)
#    - Writing outputs (0.96 seconds; tNow = 17000.0)
#    - Write sediment mesh output 15.687523
# tNow = 17226.0 (step took 28.06 seconds)
# tNow = 17866.0 (step took 1.75 seconds)
#    - Writing outputs (0.95 seconds; tNow = 18000.0)
#    - Write sediment mesh output 15.482724
# tNow = 18201.0 (step took 28.00 seconds)
# tNow = 18889.0 (step took 1.86 seconds)
#    - Writing outputs (0.93 seconds; tNow = 19000.0)
#    - Write sediment mesh output 15.476888
# tNow = 19209.0 (step took 28.60 seconds)
# tNow = 19844.0 (step took 1.87 seconds)
#    - Writing outputs (0.94 seconds; tNow = 20000.0)
#    - Write sediment mesh output 15.475517
# tNow = 20210.0 (step took 29.30 seconds)
# tNow = 20946.0 (step took 2.01 seconds)
#    - Writing outputs (0.95 seconds; tNow = 21000.0)
#    - Write sediment mesh output 16.102252
# tNow = 21317.0 (step took 30.46 seconds)
# tNow = 22000.0 (step took 1.99 seconds)
#    - Writing outputs (0.94 seconds; tNow = 22000.0)
#    - Write sediment mesh output 15.947271
# tNow = 22232.0 (step took 30.73 seconds)
# tNow = 22890.0 (step took 2.06 seconds)
#    - Writing outputs (0.94 seconds; tNow = 23000.0)
#    - Write sediment mesh output 16.133528
# tNow = 23239.0 (step took 32.05 seconds)
# tNow = 23940.0 (step took 2.29 seconds)
#    - Writing outputs (0.95 seconds; tNow = 24000.0)
#    - Write sediment mesh output 16.816222
# tNow = 24218.0 (step took 33.58 seconds)
# tNow = 24880.0 (step took 2.20 seconds)
#    - Writing outputs (0.93 seconds; tNow = 25000.0)
#    - Write sediment mesh output 16.040466
# tNow = 25251.0 (step took 32.27 seconds)
# tNow = 26000.0 (step took 2.22 seconds)
#    - Writing outputs (0.94 seconds; tNow = 26000.0)
#    - Write sediment mesh output 15.924572
# tNow = 26210.0 (step took 32.48 seconds)
# tNow = 26898.0 (step took 2.30 seconds)
#    - Writing outputs (0.93 seconds; tNow = 27000.0)
#    - Write sediment mesh output 16.172552
# tNow = 27211.0 (step took 33.23 seconds)
# tNow = 27887.0 (step took 2.32 seconds)
#    - Writing outputs (0.93 seconds; tNow = 28000.0)
#    - Write sediment mesh output 16.101123
# tNow = 28253.0 (step took 33.57 seconds)
# tNow = 28801.0 (step took 2.41 seconds)
#    - Writing outputs (0.93 seconds; tNow = 29000.0)
#    - Write sediment mesh output 16.340413
# tNow = 29211.0 (step took 34.43 seconds)
# tNow = 29867.0 (step took 2.39 seconds)
#    - Writing outputs (0.93 seconds; tNow = 30000.0)
#    - Write sediment mesh output 16.178437
# tNow = 30250.0 (step took 34.63 seconds)
# tNow = 30673.0 (step took 2.54 seconds)
# tNow = 31000.0 (step took 2.49 seconds)
#    - Writing outputs (0.93 seconds; tNow = 31000.0)
#    - Write sediment mesh output 17.13657
# tNow = 31223.0 (step took 36.16 seconds)
# tNow = 31626.0 (step took 2.56 seconds)
# tNow = 32000.0 (step took 2.57 seconds)
#    - Writing outputs (0.94 seconds; tNow = 32000.0)
#    - Write sediment mesh output 16.366964
# tNow = 32216.0 (step took 36.25 seconds)
# tNow = 32711.0 (step took 2.73 seconds)
#    - Writing outputs (0.96 seconds; tNow = 33000.0)
#    - Write sediment mesh output 16.873299
# tNow = 33197.0 (step took 35.86 seconds)
# tNow = 33614.0 (step took 2.61 seconds)
# tNow = 34000.0 (step took 2.70 seconds)
#    - Writing outputs (0.96 seconds; tNow = 34000.0)
#    - Write sediment mesh output 16.753017
# tNow = 34167.0 (step took 34.84 seconds)
# tNow = 34628.0 (step took 2.73 seconds)
# tNow = 35000.0 (step took 2.68 seconds)
#    - Writing outputs (0.92 seconds; tNow = 35000.0)
#    - Write sediment mesh output 16.328949
# tNow = 35223.0 (step took 35.60 seconds)
# tNow = 35690.0 (step took 2.96 seconds)
# tNow = 36000.0 (step took 2.78 seconds)
#    - Writing outputs (0.93 seconds; tNow = 36000.0)
#    - Write sediment mesh output 16.558797
# tNow = 36204.0 (step took 35.48 seconds)
# tNow = 36641.0 (step took 2.83 seconds)
# tNow = 37000.0 (step took 2.80 seconds)
#    - Writing outputs (0.92 seconds; tNow = 37000.0)
#    - Write sediment mesh output 16.561319
# tNow = 37236.0 (step took 36.18 seconds)
# tNow = 37663.0 (step took 2.98 seconds)
# tNow = 38000.0 (step took 3.00 seconds)
#    - Writing outputs (0.97 seconds; tNow = 38000.0)
#    - Write sediment mesh output 17.082443
# tNow = 38224.0 (step took 37.50 seconds)
# tNow = 38664.0 (step took 3.11 seconds)
# tNow = 39000.0 (step took 3.11 seconds)
#    - Writing outputs (0.93 seconds; tNow = 39000.0)
#    - Write sediment mesh output 16.888607
# tNow = 39195.0 (step took 37.46 seconds)
# tNow = 39602.0 (step took 3.09 seconds)
# tNow = 40000.0 (step took 3.04 seconds)
#    - Writing outputs (0.94 seconds; tNow = 40000.0)
#    - Write sediment mesh output 16.947315
# tNow = 40215.0 (step took 37.84 seconds)
# tNow = 40685.0 (step took 3.28 seconds)
# tNow = 41000.0 (step took 3.25 seconds)
#    - Writing outputs (0.93 seconds; tNow = 41000.0)
#    - Write sediment mesh output 17.072281
# tNow = 41233.0 (step took 38.85 seconds)
# tNow = 41680.0 (step took 3.26 seconds)
# tNow = 42000.0 (step took 3.26 seconds)
#    - Writing outputs (0.92 seconds; tNow = 42000.0)
#    - Write sediment mesh output 17.072856
# tNow = 42323.0 (step took 38.88 seconds)
# tNow = 42858.0 (step took 3.52 seconds)
#    - Writing outputs (0.95 seconds; tNow = 43000.0)
#    - Write sediment mesh output 17.335532
# tNow = 43338.0 (step took 40.42 seconds)
# tNow = 43808.0 (step took 3.58 seconds)
#    - Writing outputs (0.94 seconds; tNow = 44000.0)
#    - Write sediment mesh output 17.559594
# tNow = 44317.0 (step took 40.79 seconds)
# tNow = 44801.0 (step took 3.63 seconds)
#    - Writing outputs (0.92 seconds; tNow = 45000.0)
#    - Write sediment mesh output 17.328376
# tNow = 45327.0 (step took 40.38 seconds)
# tNow = 45795.0 (step took 3.46 seconds)
#    - Writing outputs (0.93 seconds; tNow = 46000.0)
#    - Write sediment mesh output 17.269008
# tNow = 46232.0 (step took 40.67 seconds)
# tNow = 46703.0 (step took 3.50 seconds)
# tNow = 47000.0 (step took 3.50 seconds)
#    - Writing outputs (0.94 seconds; tNow = 47000.0)
#    - Write sediment mesh output 17.495162
# tNow = 47232.0 (step took 42.17 seconds)
# tNow = 47820.0 (step took 4.03 seconds)
#    - Writing outputs (0.94 seconds; tNow = 48000.0)
#    - Write sediment mesh output 17.869472
# tNow = 48178.0 (step took 42.48 seconds)
# tNow = 48625.0 (step took 4.15 seconds)
# tNow = 49000.0 (step took 4.14 seconds)
#    - Writing outputs (0.93 seconds; tNow = 49000.0)
#    - Write sediment mesh output 18.177408
# tNow = 49343.0 (step took 44.22 seconds)
# tNow = 49896.0 (step took 4.15 seconds)
#    - Writing outputs (0.93 seconds; tNow = 50000.0)
#    - Write sediment mesh output 18.757522
# tNow = 50202.0 (step took 45.69 seconds)
# tNow = 50685.0 (step took 4.39 seconds)
# tNow = 51000.0 (step took 4.38 seconds)
#    - Writing outputs (0.93 seconds; tNow = 51000.0)
#    - Write sediment mesh output 18.34946
# tNow = 51187.0 (step took 44.83 seconds)
# tNow = 51535.0 (step took 4.41 seconds)
# tNow = 51997.0 (step took 4.45 seconds)
#    - Writing outputs (0.92 seconds; tNow = 52000.0)
#    - Write sediment mesh output 18.438584
# tNow = 52273.0 (step took 44.72 seconds)
# tNow = 52681.0 (step took 4.34 seconds)
# tNow = 53000.0 (step took 4.24 seconds)
#    - Writing outputs (0.93 seconds; tNow = 53000.0)
#    - Write sediment mesh output 18.496633
# tNow = 53193.0 (step took 45.81 seconds)
# tNow = 53745.0 (step took 4.47 seconds)
#    - Writing outputs (0.92 seconds; tNow = 54000.0)
#    - Write sediment mesh output 18.34022
# tNow = 54193.0 (step took 46.65 seconds)
# tNow = 54681.0 (step took 4.76 seconds)
# tNow = 55000.0 (4.62 seconds)
#    - Writing outputs (0.94 seconds; tNow = 55000.0)
#         Model Pur032 run
# Process layers at time [in years]:  0.0
# Process layers at time [in years]:  1000.0
# Process layers at time [in years]:  2000.0
# Process layers at time [in years]:  3000.0
# Process layers at time [in years]:  4000.0
# Process layers at time [in years]:  5000.0
# Process layers at time [in years]:  6000.0
# Process layers at time [in years]:  7000.0
# Process layers at time [in years]:  8000.0
# Process layers at time [in years]:  9000.0
# Process layers at time [in years]:  10000.0
# Process layers at time [in years]:  11000.0
# Process layers at time [in years]:  12000.0
# Process layers at time [in years]:  13000.0
# Process layers at time [in years]:  14000.0
# Process layers at time [in years]:  15000.0
# Process layers at time [in years]:  16000.0
# Process layers at time [in years]:  17000.0
# Process layers at time [in years]:  18000.0
# Process layers at time [in years]:  19000.0
# Process layers at time [in years]:  20000.0
# Process layers at time [in years]:  21000.0
# Process layers at time [in years]:  22000.0
# Process layers at time [in years]:  23000.0
# Process layers at time [in years]:  24000.0
# Process layers at time [in years]:  25000.0
# Process layers at time [in years]:  26000.0
# Process layers at time [in years]:  27000.0
# Process layers at time [in years]:  28000.0
# Process layers at time [in years]:  29000.0
# Process layers at time [in years]:  30000.0
# Process layers at time [in years]:  31000.0
# Process layers at time [in years]:  32000.0
# Process layers at time [in years]:  33000.0
# Process layers at time [in years]:  34000.0
# Process layers at time [in years]:  35000.0
# Process layers at time [in years]:  36000.0
# Process layers at time [in years]:  37000.0
# Process layers at time [in years]:  38000.0
# Process layers at time [in years]:  39000.0
# Process layers at time [in years]:  40000.0
# Process layers at time [in years]:  41000.0
# Process layers at time [in years]:  42000.0
# Process layers at time [in years]:  43000.0
# Process layers at time [in years]:  44000.0
# Process layers at time [in years]:  45000.0
# Process layers at time [in years]:  46000.0
# Process layers at time [in years]:  47000.0
# Process layers at time [in years]:  48000.0
# Process layers at time [in years]:  49000.0
# Process layers at time [in years]:  50000.0
# Process layers at time [in years]:  51000.0
# Process layers at time [in years]:  52000.0
# Process layers at time [in years]:  53000.0
# Process layers at time [in years]:  54000.0
# Process layers at time [in years]:  55000.0
#         Model Pur032 stratal_series created
#    - Writing outputs (1.21 seconds; tNow = 0.0)
#    - Write sediment mesh output 13.4407
#    - Writing outputs (0.92 seconds; tNow = 1000.0)
#    - Write sediment mesh output 13.483866
# tNow = 2000.0 (step took 1.00 seconds)
#    - Writing outputs (0.92 seconds; tNow = 2000.0)
#    - Write sediment mesh output 13.616331
# tNow = 2959.0 (step took 1.01 seconds)
#    - Writing outputs (0.91 seconds; tNow = 3000.0)
#    - Write sediment mesh output 13.703087
# tNow = 3619.0 (step took 1.00 seconds)
#    - Writing outputs (0.92 seconds; tNow = 4000.0)
#    - Write sediment mesh output 13.896603
# tNow = 4678.0 (step took 1.02 seconds)
#    - Writing outputs (0.91 seconds; tNow = 5000.0)
#    - Write sediment mesh output 13.955796
# tNow = 5678.0 (step took 1.04 seconds)
#    - Writing outputs (0.91 seconds; tNow = 6000.0)
#    - Write sediment mesh output 14.025958
# tNow = 6339.0 (step took 20.34 seconds)
#    - Writing outputs (0.91 seconds; tNow = 7000.0)
#    - Write sediment mesh output 14.546912
# tNow = 7227.0 (step took 21.51 seconds)
#    - Writing outputs (0.93 seconds; tNow = 8000.0)
#    - Write sediment mesh output 14.522237
# tNow = 8229.0 (step took 21.91 seconds)
#    - Writing outputs (0.94 seconds; tNow = 9000.0)
#    - Write sediment mesh output 14.908605
# tNow = 9339.0 (step took 22.74 seconds)
#    - Writing outputs (0.92 seconds; tNow = 10000.0)
#    - Write sediment mesh output 14.406826
# tNow = 10236.0 (step took 22.43 seconds)
#    - Writing outputs (0.92 seconds; tNow = 11000.0)
#    - Write sediment mesh output 14.900325
# tNow = 11310.0 (step took 23.71 seconds)
#    - Writing outputs (0.91 seconds; tNow = 12000.0)
#    - Write sediment mesh output 14.776693
# tNow = 12243.0 (step took 24.13 seconds)
#    - Writing outputs (0.96 seconds; tNow = 13000.0)
#    - Write sediment mesh output 15.228119
# tNow = 13208.0 (step took 24.97 seconds)
#    - Writing outputs (0.93 seconds; tNow = 14000.0)
#    - Write sediment mesh output 15.576305
# tNow = 14313.0 (step took 26.30 seconds)
# tNow = 15000.0 (step took 1.67 seconds)
#    - Writing outputs (0.99 seconds; tNow = 15000.0)
#    - Write sediment mesh output 15.700422
# tNow = 15247.0 (step took 26.79 seconds)
# tNow = 16000.0 (step took 1.71 seconds)
#    - Writing outputs (0.98 seconds; tNow = 16000.0)
#    - Write sediment mesh output 15.726406
# tNow = 16282.0 (step took 27.23 seconds)
# tNow = 17000.0 (step took 1.82 seconds)
#    - Writing outputs (0.98 seconds; tNow = 17000.0)
#    - Write sediment mesh output 16.012596
# tNow = 17338.0 (step took 28.59 seconds)
#    - Writing outputs (0.96 seconds; tNow = 18000.0)
#    - Write sediment mesh output 15.624973
# tNow = 18331.0 (step took 28.44 seconds)
# tNow = 19000.0 (step took 1.89 seconds)
#    - Writing outputs (0.96 seconds; tNow = 19000.0)
#    - Write sediment mesh output 15.769021
# tNow = 19266.0 (step took 29.25 seconds)
# tNow = 20000.0 (step took 1.90 seconds)
#    - Writing outputs (0.93 seconds; tNow = 20000.0)
#    - Write sediment mesh output 15.471357
# tNow = 20218.0 (step took 29.31 seconds)
# tNow = 21000.0 (step took 1.92 seconds)
#    - Writing outputs (0.98 seconds; tNow = 21000.0)
#    - Write sediment mesh output 15.701335
# tNow = 21221.0 (step took 29.85 seconds)
# tNow = 22000.0 (step took 1.95 seconds)
#    - Writing outputs (0.94 seconds; tNow = 22000.0)
#    - Write sediment mesh output 15.75439
# tNow = 22238.0 (step took 30.24 seconds)
# tNow = 22929.0 (step took 2.06 seconds)
#    - Writing outputs (0.93 seconds; tNow = 23000.0)
#    - Write sediment mesh output 15.942316
# tNow = 23218.0 (step took 30.92 seconds)
# tNow = 24000.0 (step took 2.10 seconds)
#    - Writing outputs (0.93 seconds; tNow = 24000.0)
#    - Write sediment mesh output 16.130745
# tNow = 24212.0 (step took 32.20 seconds)
# tNow = 24924.0 (step took 2.22 seconds)
#    - Writing outputs (0.97 seconds; tNow = 25000.0)
#    - Write sediment mesh output 16.310711
# tNow = 25276.0 (step took 32.76 seconds)
# tNow = 25801.0 (step took 2.30 seconds)
#    - Writing outputs (0.96 seconds; tNow = 26000.0)
#    - Write sediment mesh output 16.20878
# tNow = 26279.0 (step took 33.09 seconds)
# tNow = 26955.0 (step took 2.36 seconds)
#    - Writing outputs (0.94 seconds; tNow = 27000.0)
#    - Write sediment mesh output 16.495114
# tNow = 27178.0 (step took 33.68 seconds)
# tNow = 28000.0 (step took 2.37 seconds)
#    - Writing outputs (0.93 seconds; tNow = 28000.0)
#    - Write sediment mesh output 16.4972
# tNow = 28187.0 (step took 34.46 seconds)
# tNow = 28852.0 (step took 2.42 seconds)
#    - Writing outputs (0.94 seconds; tNow = 29000.0)
#    - Write sediment mesh output 16.408773
# tNow = 29223.0 (step took 34.57 seconds)
# tNow = 29722.0 (step took 2.47 seconds)
# tNow = 30000.0 (step took 2.48 seconds)
#    - Writing outputs (0.98 seconds; tNow = 30000.0)
#    - Write sediment mesh output 16.645699
# tNow = 30202.0 (step took 35.38 seconds)
# tNow = 30648.0 (step took 2.54 seconds)
# tNow = 31000.0 (step took 2.51 seconds)
#    - Writing outputs (0.93 seconds; tNow = 31000.0)
#    - Write sediment mesh output 16.259026
# tNow = 31284.0 (step took 35.64 seconds)
# tNow = 31767.0 (step took 2.64 seconds)
#    - Writing outputs (0.93 seconds; tNow = 32000.0)
#    - Write sediment mesh output 16.606006
# tNow = 32223.0 (step took 36.35 seconds)
# tNow = 32673.0 (step took 2.69 seconds)
# tNow = 33000.0 (step took 2.70 seconds)
#    - Writing outputs (0.94 seconds; tNow = 33000.0)
#    - Write sediment mesh output 16.778431
# tNow = 33279.0 (step took 35.20 seconds)
# tNow = 33743.0 (step took 2.74 seconds)
# tNow = 34000.0 (step took 2.78 seconds)
#    - Writing outputs (0.97 seconds; tNow = 34000.0)
#    - Write sediment mesh output 16.563872
# tNow = 34190.0 (step took 35.13 seconds)
# tNow = 34691.0 (step took 2.88 seconds)
# tNow = 35000.0 (step took 2.81 seconds)
#    - Writing outputs (0.95 seconds; tNow = 35000.0)
#    - Write sediment mesh output 16.823643
# tNow = 35209.0 (step took 35.93 seconds)
# tNow = 35598.0 (step took 2.85 seconds)
# tNow = 35993.0 (step took 2.79 seconds)
#    - Writing outputs (0.95 seconds; tNow = 36000.0)
#    - Write sediment mesh output 17.063261
# tNow = 36192.0 (step took 36.42 seconds)
# tNow = 36562.0 (step took 2.88 seconds)
# tNow = 36997.0 (step took 2.92 seconds)
#    - Writing outputs (0.97 seconds; tNow = 37000.0)
#    - Write sediment mesh output 17.125968
# tNow = 37185.0 (step took 37.35 seconds)
# tNow = 37735.0 (step took 3.04 seconds)
#    - Writing outputs (0.95 seconds; tNow = 38000.0)
#    - Write sediment mesh output 17.118831
# tNow = 38197.0 (step took 37.95 seconds)
# tNow = 38727.0 (step took 3.37 seconds)
# tNow = 39000.0 (step took 3.29 seconds)
#    - Writing outputs (0.97 seconds; tNow = 39000.0)
#    - Write sediment mesh output 17.289864
# tNow = 39286.0 (step took 37.97 seconds)
# tNow = 39760.0 (step took 3.09 seconds)
#    - Writing outputs (0.95 seconds; tNow = 40000.0)
#    - Write sediment mesh output 17.338683
# tNow = 40236.0 (step took 38.92 seconds)
# tNow = 40812.0 (step took 3.53 seconds)
#    - Writing outputs (0.96 seconds; tNow = 41000.0)
#    - Write sediment mesh output 17.341318
# tNow = 41222.0 (step took 39.49 seconds)
# tNow = 41778.0 (step took 3.37 seconds)
# tNow = 42000.0 (step took 3.34 seconds)
#    - Writing outputs (0.94 seconds; tNow = 42000.0)
#    - Write sediment mesh output 17.585764
# tNow = 42206.0 (step took 39.60 seconds)
# tNow = 42780.0 (step took 3.62 seconds)
# tNow = 43000.0 (step took 3.49 seconds)
#    - Writing outputs (0.95 seconds; tNow = 43000.0)
#    - Write sediment mesh output 18.114411
# tNow = 43212.0 (step took 41.05 seconds)
# tNow = 43649.0 (step took 3.56 seconds)
# tNow = 44000.0 (step took 3.57 seconds)
#    - Writing outputs (0.95 seconds; tNow = 44000.0)
#    - Write sediment mesh output 17.757774
# tNow = 44216.0 (step took 40.69 seconds)
# tNow = 44739.0 (step took 3.74 seconds)
#    - Writing outputs (0.94 seconds; tNow = 45000.0)
#    - Write sediment mesh output 18.037476
# tNow = 45288.0 (step took 41.52 seconds)
# tNow = 45894.0 (step took 3.71 seconds)
#    - Writing outputs (0.97 seconds; tNow = 46000.0)
#    - Write sediment mesh output 18.194664
# tNow = 46199.0 (step took 42.22 seconds)
# tNow = 46606.0 (step took 3.56 seconds)
# tNow = 47000.0 (step took 3.57 seconds)
#    - Writing outputs (0.96 seconds; tNow = 47000.0)
#    - Write sediment mesh output 18.207701
# tNow = 47220.0 (step took 42.90 seconds)
# tNow = 47696.0 (step took 4.05 seconds)
#    - Writing outputs (0.93 seconds; tNow = 48000.0)
#    - Write sediment mesh output 17.567217
# tNow = 48266.0 (step took 42.60 seconds)
# tNow = 48857.0 (step took 4.17 seconds)
#    - Writing outputs (0.93 seconds; tNow = 49000.0)
#    - Write sediment mesh output 18.074278
# tNow = 49269.0 (step took 43.44 seconds)
# tNow = 49680.0 (step took 3.90 seconds)
# tNow = 50000.0 (step took 3.90 seconds)
#    - Writing outputs (0.94 seconds; tNow = 50000.0)
#    - Write sediment mesh output 18.080856
# tNow = 50268.0 (step took 44.57 seconds)
# tNow = 50741.0 (step took 4.33 seconds)
# tNow = 51000.0 (step took 4.36 seconds)
#    - Writing outputs (0.98 seconds; tNow = 51000.0)
#    - Write sediment mesh output 18.271159
# tNow = 51285.0 (step took 45.65 seconds)
# tNow = 51856.0 (step took 4.57 seconds)
#    - Writing outputs (0.94 seconds; tNow = 52000.0)
#    - Write sediment mesh output 18.256154
# tNow = 52211.0 (step took 44.89 seconds)
# tNow = 52632.0 (step took 4.34 seconds)
# tNow = 53000.0 (step took 4.26 seconds)
#    - Writing outputs (0.94 seconds; tNow = 53000.0)
#    - Write sediment mesh output 18.590759
# tNow = 53288.0 (step took 46.25 seconds)
# tNow = 53907.0 (step took 4.47 seconds)
#    - Writing outputs (0.93 seconds; tNow = 54000.0)
#    - Write sediment mesh output 18.498586
# tNow = 54294.0 (step took 46.46 seconds)
# tNow = 54822.0 (step took 4.75 seconds)
# tNow = 55000.0 (4.71 seconds)
#    - Writing outputs (0.93 seconds; tNow = 55000.0)
#         Model Pur033 run
# Process layers at time [in years]:  0.0
# Process layers at time [in years]:  1000.0
# Process layers at time [in years]:  2000.0
# Process layers at time [in years]:  3000.0
# Process layers at time [in years]:  4000.0
# Process layers at time [in years]:  5000.0
# Process layers at time [in years]:  6000.0
# Process layers at time [in years]:  7000.0
# Process layers at time [in years]:  8000.0
# Process layers at time [in years]:  9000.0
# Process layers at time [in years]:  10000.0
# Process layers at time [in years]:  11000.0
# Process layers at time [in years]:  12000.0
# Process layers at time [in years]:  13000.0
# Process layers at time [in years]:  14000.0
# Process layers at time [in years]:  15000.0
# Process layers at time [in years]:  16000.0
# Process layers at time [in years]:  17000.0
# Process layers at time [in years]:  18000.0
# Process layers at time [in years]:  19000.0
# Process layers at time [in years]:  20000.0
# Process layers at time [in years]:  21000.0
# Process layers at time [in years]:  22000.0
# Process layers at time [in years]:  23000.0
# Process layers at time [in years]:  24000.0
# Process layers at time [in years]:  25000.0
# Process layers at time [in years]:  26000.0
# Process layers at time [in years]:  27000.0
# Process layers at time [in years]:  28000.0
# Process layers at time [in years]:  29000.0
# Process layers at time [in years]:  30000.0
# Process layers at time [in years]:  31000.0
# Process layers at time [in years]:  32000.0
# Process layers at time [in years]:  33000.0
# Process layers at time [in years]:  34000.0
# Process layers at time [in years]:  35000.0
# Process layers at time [in years]:  36000.0
# Process layers at time [in years]:  37000.0
# Process layers at time [in years]:  38000.0
# Process layers at time [in years]:  39000.0
# Process layers at time [in years]:  40000.0
# Process layers at time [in years]:  41000.0
# Process layers at time [in years]:  42000.0
# Process layers at time [in years]:  43000.0
# Process layers at time [in years]:  44000.0
# Process layers at time [in years]:  45000.0
# Process layers at time [in years]:  46000.0
# Process layers at time [in years]:  47000.0
# Process layers at time [in years]:  48000.0
# Process layers at time [in years]:  49000.0
# Process layers at time [in years]:  50000.0
# Process layers at time [in years]:  51000.0
# Process layers at time [in years]:  52000.0
# Process layers at time [in years]:  53000.0
# Process layers at time [in years]:  54000.0
# Process layers at time [in years]:  55000.0
#         Model Pur033 stratal_series created
#    - Writing outputs (1.24 seconds; tNow = 0.0)
#    - Write sediment mesh output 13.676327
#    - Writing outputs (0.94 seconds; tNow = 1000.0)
#    - Write sediment mesh output 13.728758
# tNow = 2000.0 (step took 1.01 seconds)
#    - Writing outputs (0.93 seconds; tNow = 2000.0)
#    - Write sediment mesh output 13.916747
# tNow = 2803.0 (step took 1.07 seconds)
#    - Writing outputs (0.94 seconds; tNow = 3000.0)
#    - Write sediment mesh output 13.982944
# tNow = 4000.0 (step took 0.99 seconds)
#    - Writing outputs (0.93 seconds; tNow = 4000.0)
#    - Write sediment mesh output 13.998493
# tNow = 4678.0 (step took 1.01 seconds)
#    - Writing outputs (0.93 seconds; tNow = 5000.0)
#    - Write sediment mesh output 14.098053
# tNow = 5678.0 (step took 1.02 seconds)
#    - Writing outputs (0.94 seconds; tNow = 6000.0)
#    - Write sediment mesh output 14.306506
# tNow = 6301.0 (step took 20.52 seconds)
#    - Writing outputs (0.93 seconds; tNow = 7000.0)
#    - Write sediment mesh output 14.343957
# tNow = 7339.0 (step took 21.21 seconds)
#    - Writing outputs (0.94 seconds; tNow = 8000.0)
#    - Write sediment mesh output 14.837406
# tNow = 8339.0 (step took 22.41 seconds)
#    - Writing outputs (0.93 seconds; tNow = 9000.0)
#    - Write sediment mesh output 14.793787
# tNow = 9306.0 (step took 22.61 seconds)
#    - Writing outputs (0.93 seconds; tNow = 10000.0)
#    - Write sediment mesh output 14.740736
# tNow = 10339.0 (step took 23.00 seconds)
#    - Writing outputs (0.94 seconds; tNow = 11000.0)
#    - Write sediment mesh output 14.960401
# tNow = 11297.0 (step took 23.92 seconds)
#    - Writing outputs (0.97 seconds; tNow = 12000.0)
#    - Write sediment mesh output 15.241594
# tNow = 12339.0 (step took 24.78 seconds)
#    - Writing outputs (0.95 seconds; tNow = 13000.0)
#    - Write sediment mesh output 15.347651
# tNow = 13271.0 (step took 25.42 seconds)
# tNow = 14000.0 (step took 1.58 seconds)
#    - Writing outputs (0.97 seconds; tNow = 14000.0)
#    - Write sediment mesh output 15.254725
# tNow = 14334.0 (step took 25.67 seconds)
#    - Writing outputs (0.96 seconds; tNow = 15000.0)
#    - Write sediment mesh output 15.471656
# tNow = 15281.0 (step took 26.34 seconds)
# tNow = 15993.0 (step took 1.68 seconds)
#    - Writing outputs (0.93 seconds; tNow = 16000.0)
#    - Write sediment mesh output 15.452062
# tNow = 16198.0 (step took 26.72 seconds)
# tNow = 16816.0 (step took 1.81 seconds)
#    - Writing outputs (0.96 seconds; tNow = 17000.0)
#    - Write sediment mesh output 15.894651
# tNow = 17197.0 (step took 28.00 seconds)
# tNow = 17867.0 (step took 1.75 seconds)
#    - Writing outputs (0.93 seconds; tNow = 18000.0)
#    - Write sediment mesh output 15.411573
# tNow = 18214.0 (step took 27.90 seconds)
# tNow = 18919.0 (step took 1.85 seconds)
#    - Writing outputs (0.94 seconds; tNow = 19000.0)
#    - Write sediment mesh output 15.670574
# tNow = 19263.0 (step took 28.80 seconds)
# tNow = 19877.0 (step took 1.87 seconds)
#    - Writing outputs (0.94 seconds; tNow = 20000.0)
#    - Write sediment mesh output 15.664764
# tNow = 20295.0 (step took 29.57 seconds)
# tNow = 20981.0 (step took 1.95 seconds)
#    - Writing outputs (0.93 seconds; tNow = 21000.0)
#    - Write sediment mesh output 15.657164
# tNow = 21218.0 (step took 29.85 seconds)
# tNow = 21907.0 (step took 2.12 seconds)
#    - Writing outputs (0.99 seconds; tNow = 22000.0)
#    - Write sediment mesh output 16.081659
# tNow = 22206.0 (step took 30.84 seconds)
# tNow = 22901.0 (step took 2.05 seconds)
#    - Writing outputs (0.97 seconds; tNow = 23000.0)
#    - Write sediment mesh output 15.953389
# tNow = 23283.0 (step took 31.02 seconds)
# tNow = 23968.0 (step took 2.14 seconds)
#    - Writing outputs (0.93 seconds; tNow = 24000.0)
#    - Write sediment mesh output 15.899406
# tNow = 24198.0 (step took 31.86 seconds)
# tNow = 24938.0 (step took 2.24 seconds)
#    - Writing outputs (0.93 seconds; tNow = 25000.0)
#    - Write sediment mesh output 16.019636
# tNow = 25195.0 (step took 32.26 seconds)
# tNow = 25782.0 (step took 2.26 seconds)
#    - Writing outputs (0.95 seconds; tNow = 26000.0)
#    - Write sediment mesh output 16.168889
# tNow = 26195.0 (step took 33.03 seconds)
# tNow = 26781.0 (step took 2.37 seconds)
#    - Writing outputs (0.94 seconds; tNow = 27000.0)
#    - Write sediment mesh output 16.097509
# tNow = 27172.0 (step took 33.51 seconds)
# tNow = 27748.0 (step took 2.36 seconds)
#    - Writing outputs (0.93 seconds; tNow = 28000.0)
#    - Write sediment mesh output 16.21345
# tNow = 28181.0 (step took 34.63 seconds)
# tNow = 28582.0 (step took 2.55 seconds)
# tNow = 28973.0 (step took 2.53 seconds)
#    - Writing outputs (0.96 seconds; tNow = 29000.0)
#    - Write sediment mesh output 16.834676
# tNow = 29197.0 (step took 35.52 seconds)
# tNow = 29880.0 (step took 2.42 seconds)
#    - Writing outputs (0.93 seconds; tNow = 30000.0)
#    - Write sediment mesh output 16.29256
# tNow = 30179.0 (step took 34.92 seconds)
# tNow = 30639.0 (step took 2.52 seconds)
# tNow = 31000.0 (step took 2.51 seconds)
#    - Writing outputs (0.93 seconds; tNow = 31000.0)
#    - Write sediment mesh output 16.367345
# tNow = 31185.0 (step took 35.53 seconds)
# tNow = 31556.0 (step took 2.58 seconds)
# tNow = 31931.0 (step took 2.56 seconds)
#    - Writing outputs (0.95 seconds; tNow = 32000.0)
#    - Write sediment mesh output 16.297787
# tNow = 32199.0 (step took 36.17 seconds)
# tNow = 32600.0 (step took 2.64 seconds)
# tNow = 32982.0 (step took 2.62 seconds)
#    - Writing outputs (0.94 seconds; tNow = 33000.0)
#    - Write sediment mesh output 16.384804
# tNow = 33284.0 (step took 34.34 seconds)
# tNow = 33671.0 (step took 2.62 seconds)
# tNow = 34000.0 (step took 2.63 seconds)
#    - Writing outputs (0.93 seconds; tNow = 34000.0)
#    - Write sediment mesh output 16.554736
# tNow = 34190.0 (step took 34.85 seconds)
# tNow = 34674.0 (step took 2.82 seconds)
# tNow = 35000.0 (step took 2.85 seconds)
#    - Writing outputs (0.96 seconds; tNow = 35000.0)
#    - Write sediment mesh output 17.192637
# tNow = 35193.0 (step took 36.63 seconds)
# tNow = 35582.0 (step took 2.78 seconds)
# tNow = 35967.0 (step took 2.84 seconds)
#    - Writing outputs (0.94 seconds; tNow = 36000.0)
#    - Write sediment mesh output 16.903131
# tNow = 36195.0 (step took 36.78 seconds)
# tNow = 36585.0 (step took 3.27 seconds)
# tNow = 37000.0 (step took 3.10 seconds)
#    - Writing outputs (0.97 seconds; tNow = 37000.0)
#    - Write sediment mesh output 17.625289
# tNow = 37181.0 (step took 38.95 seconds)
# tNow = 37571.0 (step took 3.62 seconds)
# tNow = 37949.0 (step took 3.41 seconds)
#    - Writing outputs (0.97 seconds; tNow = 38000.0)
#    - Write sediment mesh output 17.83345
# tNow = 38193.0 (step took 39.41 seconds)
# tNow = 38583.0 (step took 3.09 seconds)
# tNow = 39000.0 (step took 3.43 seconds)
#    - Writing outputs (1.02 seconds; tNow = 39000.0)
#    - Write sediment mesh output 17.708474
# tNow = 39188.0 (step took 39.24 seconds)
# tNow = 39592.0 (step took 3.09 seconds)
# tNow = 39963.0 (step took 3.05 seconds)
#    - Writing outputs (0.95 seconds; tNow = 40000.0)
#    - Write sediment mesh output 17.446123
# tNow = 40185.0 (step took 39.29 seconds)
# tNow = 40545.0 (step took 3.40 seconds)
# tNow = 40925.0 (step took 3.48 seconds)
#    - Writing outputs (0.95 seconds; tNow = 41000.0)
#    - Write sediment mesh output 17.295447
# tNow = 41200.0 (step took 39.49 seconds)
# tNow = 41699.0 (step took 3.39 seconds)
# tNow = 42000.0 (step took 3.31 seconds)
#    - Writing outputs (0.95 seconds; tNow = 42000.0)
#    - Write sediment mesh output 17.398563
# tNow = 42199.0 (step took 39.74 seconds)
# tNow = 42597.0 (step took 3.48 seconds)
# tNow = 43000.0 (step took 3.49 seconds)
#    - Writing outputs (0.97 seconds; tNow = 43000.0)
#    - Write sediment mesh output 17.729544
# tNow = 43203.0 (step took 40.96 seconds)
# tNow = 43600.0 (step took 3.61 seconds)
# tNow = 43997.0 (step took 3.55 seconds)
#    - Writing outputs (0.98 seconds; tNow = 44000.0)
#    - Write sediment mesh output 17.94951
# tNow = 44216.0 (step took 41.43 seconds)
# tNow = 44654.0 (step took 3.89 seconds)
# tNow = 45000.0 (step took 3.76 seconds)
#    - Writing outputs (0.96 seconds; tNow = 45000.0)
#    - Write sediment mesh output 17.615557
# tNow = 45206.0 (step took 41.93 seconds)
# tNow = 45610.0 (step took 3.64 seconds)
# tNow = 46000.0 (step took 3.61 seconds)
#    - Writing outputs (0.98 seconds; tNow = 46000.0)
#    - Write sediment mesh output 17.943507
# tNow = 46190.0 (step took 42.00 seconds)
# tNow = 46704.0 (step took 3.62 seconds)
# tNow = 47000.0 (step took 3.50 seconds)
#    - Writing outputs (0.95 seconds; tNow = 47000.0)
#    - Write sediment mesh output 17.609781
# tNow = 47194.0 (step took 42.72 seconds)
# tNow = 47627.0 (step took 4.06 seconds)
# tNow = 48000.0 (step took 4.04 seconds)
#    - Writing outputs (0.94 seconds; tNow = 48000.0)
#    - Write sediment mesh output 18.185011
# tNow = 48219.0 (step took 43.18 seconds)
# tNow = 48645.0 (step took 4.25 seconds)
# tNow = 49000.0 (step took 4.23 seconds)
#    - Writing outputs (0.94 seconds; tNow = 49000.0)
#    - Write sediment mesh output 18.259322
# tNow = 49210.0 (step took 44.02 seconds)
# tNow = 49746.0 (step took 3.97 seconds)
# tNow = 50000.0 (step took 3.95 seconds)
#    - Writing outputs (0.95 seconds; tNow = 50000.0)
#    - Write sediment mesh output 18.327015
# tNow = 50320.0 (step took 44.85 seconds)
# tNow = 50950.0 (step took 4.32 seconds)
#    - Writing outputs (0.94 seconds; tNow = 51000.0)
#    - Write sediment mesh output 18.418241
# tNow = 51312.0 (step took 45.70 seconds)
# tNow = 51756.0 (step took 4.46 seconds)
#    - Writing outputs (0.92 seconds; tNow = 52000.0)
#    - Write sediment mesh output 18.216306
# tNow = 52220.0 (step took 44.38 seconds)
# tNow = 52758.0 (step took 4.19 seconds)
#    - Writing outputs (0.92 seconds; tNow = 53000.0)
#    - Write sediment mesh output 18.225708
# tNow = 53212.0 (step took 45.11 seconds)
# tNow = 53736.0 (step took 4.39 seconds)
# tNow = 54000.0 (step took 4.36 seconds)
#    - Writing outputs (0.91 seconds; tNow = 54000.0)
#    - Write sediment mesh output 18.213409
# tNow = 54214.0 (step took 45.92 seconds)
# tNow = 54736.0 (step took 4.71 seconds)
# tNow = 55000.0 (4.69 seconds)
#    - Writing outputs (0.91 seconds; tNow = 55000.0)
#         Model Pur034 run
# Process layers at time [in years]:  0.0
# Process layers at time [in years]:  1000.0
# Process layers at time [in years]:  2000.0
# Process layers at time [in years]:  3000.0
# Process layers at time [in years]:  4000.0
# Process layers at time [in years]:  5000.0
# Process layers at time [in years]:  6000.0
# Process layers at time [in years]:  7000.0
# Process layers at time [in years]:  8000.0
# Process layers at time [in years]:  9000.0
# Process layers at time [in years]:  10000.0
# Process layers at time [in years]:  11000.0
# Process layers at time [in years]:  12000.0
# Process layers at time [in years]:  13000.0
# Process layers at time [in years]:  14000.0
# Process layers at time [in years]:  15000.0
# Process layers at time [in years]:  16000.0
# Process layers at time [in years]:  17000.0
# Process layers at time [in years]:  18000.0
# Process layers at time [in years]:  19000.0
# Process layers at time [in years]:  20000.0
# Process layers at time [in years]:  21000.0
# Process layers at time [in years]:  22000.0
# Process layers at time [in years]:  23000.0
# Process layers at time [in years]:  24000.0
# Process layers at time [in years]:  25000.0
# Process layers at time [in years]:  26000.0
# Process layers at time [in years]:  27000.0
# Process layers at time [in years]:  28000.0
# Process layers at time [in years]:  29000.0
# Process layers at time [in years]:  30000.0
# Process layers at time [in years]:  31000.0
# Process layers at time [in years]:  32000.0
# Process layers at time [in years]:  33000.0
# Process layers at time [in years]:  34000.0
# Process layers at time [in years]:  35000.0
# Process layers at time [in years]:  36000.0
# Process layers at time [in years]:  37000.0
# Process layers at time [in years]:  38000.0
# Process layers at time [in years]:  39000.0
# Process layers at time [in years]:  40000.0
# Process layers at time [in years]:  41000.0
# Process layers at time [in years]:  42000.0
# ...
# Process layers at time [in years]:  16000.0
# Process layers at time [in years]:  17000.0
# Process layers at time [in years]:  18000.0
# Process layers at time [in years]:  19000.0
# Process layers at time [in years]:  20000.0
# Process layers at time [in years]:  21000.0
# Process layers at time [in years]:  22000.0
# Process layers at time [in years]:  23000.0
# Process layers at time [in years]:  24000.0
# Process layers at time [in years]:  25000.0
# Process layers at time [in years]:  26000.0
# Process layers at time [in years]:  27000.0
# Process layers at time [in years]:  28000.0
# Process layers at time [in years]:  29000.0
# Process layers at time [in years]:  30000.0
# Process layers at time [in years]:  31000.0
# Process layers at time [in years]:  32000.0
# Process layers at time [in years]:  33000.0
# Process layers at time [in years]:  34000.0
# Process layers at time [in years]:  35000.0
# Process layers at time [in years]:  36000.0
# Process layers at time [in years]:  37000.0
# Process layers at time [in years]:  38000.0
# Process layers at time [in years]:  39000.0
# Process layers at time [in years]:  40000.0
# Process layers at time [in years]:  41000.0
# Process layers at time [in years]:  42000.0
# Process layers at time [in years]:  43000.0
# Process layers at time [in years]:  44000.0
# Process layers at time [in years]:  45000.0
# Process layers at time [in years]:  46000.0
# Process layers at time [in years]:  47000.0
# Process layers at time [in years]:  48000.0
# Process layers at time [in years]:  49000.0
# Process layers at time [in years]:  50000.0
# Process layers at time [in years]:  51000.0
# Process layers at time [in years]:  52000.0
# Process layers at time [in years]:  53000.0
# Process layers at time [in years]:  54000.0
# Process layers at time [in years]:  55000.0
#         Model Pur039 stratal_series created
#    - Writing outputs (1.21 seconds; tNow = 0.0)
#    - Write sediment mesh output 13.553835
#    - Writing outputs (0.91 seconds; tNow = 1000.0)
#    - Write sediment mesh output 13.543152
# tNow = 2000.0 (step took 1.01 seconds)
#    - Writing outputs (0.91 seconds; tNow = 2000.0)
#    - Write sediment mesh output 13.645282
# tNow = 2221.0 (step took 1.07 seconds)
#    - Writing outputs (0.91 seconds; tNow = 3000.0)
#    - Write sediment mesh output 13.714756
# tNow = 3750.0 (step took 0.98 seconds)
#    - Writing outputs (0.91 seconds; tNow = 4000.0)
#    - Write sediment mesh output 13.82709
# tNow = 4457.0 (step took 1.00 seconds)
#    - Writing outputs (0.91 seconds; tNow = 5000.0)
#    - Write sediment mesh output 14.038921
# tNow = 5374.0 (step took 1.02 seconds)
#    - Writing outputs (0.92 seconds; tNow = 6000.0)
#    - Write sediment mesh output 14.173935
# tNow = 6142.0 (step took 20.28 seconds)
# tNow = 7000.0 (step took 1.02 seconds)
#    - Writing outputs (0.92 seconds; tNow = 7000.0)
#    - Write sediment mesh output 14.22361
# tNow = 7145.0 (step took 20.95 seconds)
# tNow = 8000.0 (step took 1.23 seconds)
#    - Writing outputs (0.91 seconds; tNow = 8000.0)
#    - Write sediment mesh output 14.257958
# tNow = 8167.0 (step took 21.46 seconds)
# tNow = 8827.0 (step took 1.29 seconds)
#    - Writing outputs (0.91 seconds; tNow = 9000.0)
#    - Write sediment mesh output 14.299478
# tNow = 9177.0 (step took 21.86 seconds)
# tNow = 9899.0 (step took 1.31 seconds)
#    - Writing outputs (0.91 seconds; tNow = 10000.0)
#    - Write sediment mesh output 14.397805
# tNow = 10146.0 (step took 22.61 seconds)
# tNow = 10883.0 (step took 1.38 seconds)
#    - Writing outputs (0.91 seconds; tNow = 11000.0)
#    - Write sediment mesh output 14.533682
# tNow = 11168.0 (step took 22.98 seconds)
# tNow = 11853.0 (step took 1.43 seconds)
#    - Writing outputs (0.91 seconds; tNow = 12000.0)
#    - Write sediment mesh output 14.619939
# tNow = 12146.0 (step took 23.46 seconds)
# tNow = 12777.0 (step took 1.48 seconds)
#    - Writing outputs (0.91 seconds; tNow = 13000.0)
#    - Write sediment mesh output 14.67103
# tNow = 13151.0 (step took 24.20 seconds)
# tNow = 13856.0 (step took 1.51 seconds)
#    - Writing outputs (0.91 seconds; tNow = 14000.0)
#    - Write sediment mesh output 14.806841
# tNow = 14153.0 (step took 24.80 seconds)
# tNow = 14765.0 (step took 1.58 seconds)
#    - Writing outputs (0.92 seconds; tNow = 15000.0)
#    - Write sediment mesh output 14.90351
# tNow = 15160.0 (step took 25.31 seconds)
# tNow = 15762.0 (step took 1.63 seconds)
#    - Writing outputs (0.91 seconds; tNow = 16000.0)
#    - Write sediment mesh output 15.025832
# tNow = 16163.0 (step took 25.82 seconds)
# tNow = 16644.0 (step took 1.69 seconds)
# tNow = 17000.0 (step took 1.68 seconds)
#    - Writing outputs (0.91 seconds; tNow = 17000.0)
#    - Write sediment mesh output 15.065387
# tNow = 17201.0 (step took 26.83 seconds)
# tNow = 17615.0 (step took 1.71 seconds)
# tNow = 18000.0 (step took 1.71 seconds)
#    - Writing outputs (0.92 seconds; tNow = 18000.0)
#    - Write sediment mesh output 15.089072
# tNow = 18220.0 (step took 27.35 seconds)
# tNow = 18691.0 (step took 1.80 seconds)
#    - Writing outputs (0.92 seconds; tNow = 19000.0)
#    - Write sediment mesh output 15.292995
# tNow = 19159.0 (step took 28.05 seconds)
# tNow = 19674.0 (step took 1.85 seconds)
# tNow = 20000.0 (step took 1.85 seconds)
#    - Writing outputs (0.91 seconds; tNow = 20000.0)
#    - Write sediment mesh output 15.146489
# tNow = 20138.0 (step took 28.62 seconds)
# tNow = 20611.0 (step took 1.90 seconds)
#    - Writing outputs (0.91 seconds; tNow = 21000.0)
#    - Write sediment mesh output 15.332502
# tNow = 21155.0 (step took 29.00 seconds)
# tNow = 21647.0 (step took 1.93 seconds)
#    - Writing outputs (0.91 seconds; tNow = 22000.0)
#    - Write sediment mesh output 15.4113
# tNow = 22142.0 (step took 29.62 seconds)
# tNow = 22577.0 (step took 2.02 seconds)
# tNow = 23000.0 (step took 2.03 seconds)
#    - Writing outputs (0.91 seconds; tNow = 23000.0)
#    - Write sediment mesh output 15.569936
# tNow = 23138.0 (step took 30.21 seconds)
# tNow = 23567.0 (step took 2.06 seconds)
# tNow = 23980.0 (step took 2.07 seconds)
#    - Writing outputs (0.91 seconds; tNow = 24000.0)
#    - Write sediment mesh output 15.558991
# tNow = 24134.0 (step took 30.71 seconds)
# tNow = 24609.0 (step took 2.12 seconds)
# tNow = 25000.0 (step took 2.13 seconds)
#    - Writing outputs (0.92 seconds; tNow = 25000.0)
#    - Write sediment mesh output 15.705176
# tNow = 25136.0 (step took 31.38 seconds)
# tNow = 25598.0 (step took 2.16 seconds)
# tNow = 26000.0 (step took 2.16 seconds)
#    - Writing outputs (0.92 seconds; tNow = 26000.0)
#    - Write sediment mesh output 15.671852
# tNow = 26122.0 (step took 31.92 seconds)
# tNow = 26628.0 (step took 2.26 seconds)
# tNow = 26999.0 (step took 2.24 seconds)
#    - Writing outputs (0.91 seconds; tNow = 27000.0)
#    - Write sediment mesh output 15.893853
# tNow = 27179.0 (step took 32.66 seconds)
# tNow = 27665.0 (step took 2.33 seconds)
# tNow = 28000.0 (step took 2.29 seconds)
#    - Writing outputs (0.92 seconds; tNow = 28000.0)
#    - Write sediment mesh output 15.950045
# tNow = 28139.0 (step took 33.10 seconds)
# tNow = 28513.0 (step took 2.36 seconds)
# tNow = 28952.0 (step took 2.34 seconds)
#    - Writing outputs (0.92 seconds; tNow = 29000.0)
#    - Write sediment mesh output 16.01087
# tNow = 29197.0 (step took 33.66 seconds)
# tNow = 29629.0 (step took 2.37 seconds)
# tNow = 30000.0 (step took 2.37 seconds)
#    - Writing outputs (0.92 seconds; tNow = 30000.0)
#    - Write sediment mesh output 16.039077
# tNow = 30120.0 (step took 34.23 seconds)
# tNow = 30624.0 (step took 2.48 seconds)
# tNow = 31000.0 (step took 2.46 seconds)
#    - Writing outputs (0.91 seconds; tNow = 31000.0)
#    - Write sediment mesh output 15.906492
# tNow = 31197.0 (step took 34.35 seconds)
# tNow = 31633.0 (step took 2.51 seconds)
# tNow = 31964.0 (step took 2.51 seconds)
#    - Writing outputs (0.91 seconds; tNow = 32000.0)
#    - Write sediment mesh output 16.112011
# tNow = 32136.0 (step took 35.19 seconds)
# tNow = 32514.0 (step took 2.56 seconds)
# tNow = 32752.0 (step took 2.56 seconds)
# tNow = 33000.0 (step took 2.57 seconds)
#    - Writing outputs (0.92 seconds; tNow = 33000.0)
#    - Write sediment mesh output 16.090108
# tNow = 33197.0 (step took 33.63 seconds)
# tNow = 33499.0 (step took 2.59 seconds)
# tNow = 33759.0 (step took 2.58 seconds)
# tNow = 34000.0 (step took 2.57 seconds)
#    - Writing outputs (0.92 seconds; tNow = 34000.0)
#    - Write sediment mesh output 16.227626
# tNow = 34188.0 (step took 34.04 seconds)
# tNow = 34466.0 (step took 2.70 seconds)
# tNow = 34740.0 (step took 2.69 seconds)
# tNow = 35000.0 (step took 2.68 seconds)
#    - Writing outputs (0.92 seconds; tNow = 35000.0)
#    - Write sediment mesh output 16.218586
# tNow = 35134.0 (step took 34.71 seconds)
# tNow = 35364.0 (step took 2.75 seconds)
# tNow = 35673.0 (step took 2.75 seconds)
# tNow = 35933.0 (step took 2.74 seconds)
#    - Writing outputs (0.92 seconds; tNow = 36000.0)
#    - Write sediment mesh output 16.328777
# tNow = 36164.0 (step took 35.00 seconds)
# tNow = 36480.0 (step took 2.82 seconds)
# tNow = 36793.0 (step took 2.83 seconds)
# tNow = 37000.0 (step took 2.81 seconds)
#    - Writing outputs (0.91 seconds; tNow = 37000.0)
#    - Write sediment mesh output 16.355543
# tNow = 37180.0 (step took 35.56 seconds)
# tNow = 37448.0 (step took 2.86 seconds)
# tNow = 37720.0 (step took 2.81 seconds)
# tNow = 38000.0 (step took 2.85 seconds)
#    - Writing outputs (0.92 seconds; tNow = 38000.0)
#    - Write sediment mesh output 16.509929
# tNow = 38118.0 (step took 36.14 seconds)
# tNow = 38478.0 (step took 3.09 seconds)
# tNow = 38852.0 (step took 3.08 seconds)
#    - Writing outputs (0.91 seconds; tNow = 39000.0)
#    - Write sediment mesh output 16.999284
# tNow = 39184.0 (step took 37.16 seconds)
# tNow = 39495.0 (step took 3.04 seconds)
# tNow = 39802.0 (step took 3.06 seconds)
# tNow = 40000.0 (step took 3.04 seconds)
#    - Writing outputs (0.92 seconds; tNow = 40000.0)
#    - Write sediment mesh output 17.051463
# tNow = 40144.0 (step took 37.58 seconds)
# tNow = 40404.0 (step took 3.28 seconds)
# tNow = 40653.0 (step took 3.26 seconds)
# tNow = 40920.0 (step took 3.25 seconds)
#    - Writing outputs (0.91 seconds; tNow = 41000.0)
#    - Write sediment mesh output 16.807776
# tNow = 41142.0 (step took 37.88 seconds)
# tNow = 41416.0 (step took 3.21 seconds)
# tNow = 41766.0 (step took 3.20 seconds)
# tNow = 42000.0 (step took 3.21 seconds)
#    - Writing outputs (0.91 seconds; tNow = 42000.0)
#    - Write sediment mesh output 16.784287
# tNow = 42202.0 (step took 37.99 seconds)
# tNow = 42477.0 (step took 3.27 seconds)
# tNow = 42812.0 (step took 3.24 seconds)
# tNow = 43000.0 (step took 3.23 seconds)
#    - Writing outputs (0.91 seconds; tNow = 43000.0)
#    - Write sediment mesh output 16.801971
# tNow = 43132.0 (step took 38.72 seconds)
# tNow = 43438.0 (step took 3.43 seconds)
# tNow = 43717.0 (step took 3.42 seconds)
# tNow = 44000.0 (step took 3.41 seconds)
#    - Writing outputs (0.92 seconds; tNow = 44000.0)
#    - Write sediment mesh output 16.862102
# tNow = 44139.0 (step took 39.11 seconds)
# tNow = 44422.0 (step took 3.56 seconds)
# tNow = 44711.0 (step took 3.56 seconds)
# tNow = 45000.0 (step took 3.59 seconds)
#    - Writing outputs (0.91 seconds; tNow = 45000.0)
#    - Write sediment mesh output 17.140148
# tNow = 45196.0 (step took 39.80 seconds)
# tNow = 45536.0 (step took 3.47 seconds)
# tNow = 45823.0 (step took 3.47 seconds)
# tNow = 46000.0 (step took 3.45 seconds)
#    - Writing outputs (0.92 seconds; tNow = 46000.0)
#    - Write sediment mesh output 17.520097
# tNow = 46136.0 (step took 40.29 seconds)
# tNow = 46477.0 (step took 3.37 seconds)
# tNow = 46772.0 (step took 3.37 seconds)
# tNow = 47000.0 (step took 3.35 seconds)
#    - Writing outputs (0.91 seconds; tNow = 47000.0)
#    - Write sediment mesh output 17.113976
# tNow = 47149.0 (step took 41.04 seconds)
# tNow = 47515.0 (step took 3.93 seconds)
# tNow = 47778.0 (step took 3.91 seconds)
# tNow = 48000.0 (step took 3.90 seconds)
#    - Writing outputs (0.91 seconds; tNow = 48000.0)
#    - Write sediment mesh output 17.621331
# tNow = 48146.0 (step took 41.75 seconds)
# tNow = 48543.0 (step took 4.06 seconds)
# tNow = 48886.0 (step took 4.04 seconds)
#    - Writing outputs (0.91 seconds; tNow = 49000.0)
#    - Write sediment mesh output 17.761249
# tNow = 49202.0 (step took 42.46 seconds)
# tNow = 49444.0 (step took 3.83 seconds)
# tNow = 49700.0 (step took 3.78 seconds)
# tNow = 50000.0 (step took 3.79 seconds)
#    - Writing outputs (0.91 seconds; tNow = 50000.0)
#    - Write sediment mesh output 17.735223
# tNow = 50180.0 (step took 43.04 seconds)
# tNow = 50491.0 (step took 4.11 seconds)
# tNow = 50771.0 (step took 4.10 seconds)
# tNow = 51000.0 (step took 4.11 seconds)
#    - Writing outputs (0.91 seconds; tNow = 51000.0)
#    - Write sediment mesh output 18.015117
# tNow = 51185.0 (step took 44.06 seconds)
# tNow = 51484.0 (step took 4.30 seconds)
# tNow = 51816.0 (step took 4.28 seconds)
# tNow = 52000.0 (step took 4.29 seconds)
#    - Writing outputs (0.91 seconds; tNow = 52000.0)
#    - Write sediment mesh output 17.514885
# tNow = 52116.0 (step took 43.42 seconds)
# tNow = 52372.0 (step took 4.06 seconds)
# tNow = 52636.0 (step took 4.06 seconds)
# tNow = 52885.0 (step took 4.05 seconds)
#    - Writing outputs (0.91 seconds; tNow = 53000.0)
#    - Write sediment mesh output 17.605168
# tNow = 53145.0 (step took 44.42 seconds)
# tNow = 53467.0 (step took 4.34 seconds)
# tNow = 53722.0 (step took 4.30 seconds)
# tNow = 54000.0 (step took 4.34 seconds)
#    - Writing outputs (0.91 seconds; tNow = 54000.0)
#    - Write sediment mesh output 18.134642
# tNow = 54105.0 (step took 45.58 seconds)
# tNow = 54320.0 (step took 4.67 seconds)
# tNow = 54544.0 (step took 4.66 seconds)
# tNow = 54747.0 (step took 4.66 seconds)
# tNow = 55000.0 (4.69 seconds)
#    - Writing outputs (0.91 seconds; tNow = 55000.0)
#         Model Pur040 run
# Process layers at time [in years]:  0.0
# Process layers at time [in years]:  1000.0
# Process layers at time [in years]:  2000.0
# Process layers at time [in years]:  3000.0
# Process layers at time [in years]:  4000.0
# Process layers at time [in years]:  5000.0
# Process layers at time [in years]:  6000.0
# Process layers at time [in years]:  7000.0
# Process layers at time [in years]:  8000.0
# Process layers at time [in years]:  9000.0
# Process layers at time [in years]:  10000.0
# Process layers at time [in years]:  11000.0
# Process layers at time [in years]:  12000.0
# Process layers at time [in years]:  13000.0
# Process layers at time [in years]:  14000.0
# Process layers at time [in years]:  15000.0
# Process layers at time [in years]:  16000.0
# Process layers at time [in years]:  17000.0
# Process layers at time [in years]:  18000.0
# Process layers at time [in years]:  19000.0
# Process layers at time [in years]:  20000.0
# Process layers at time [in years]:  21000.0
# Process layers at time [in years]:  22000.0
# Process layers at time [in years]:  23000.0
# Process layers at time [in years]:  24000.0
# Process layers at time [in years]:  25000.0
# Process layers at time [in years]:  26000.0
# Process layers at time [in years]:  27000.0
# Process layers at time [in years]:  28000.0
# Process layers at time [in years]:  29000.0
# Process layers at time [in years]:  30000.0
# Process layers at time [in years]:  31000.0
# Process layers at time [in years]:  32000.0
# Process layers at time [in years]:  33000.0
# Process layers at time [in years]:  34000.0
# Process layers at time [in years]:  35000.0
# Process layers at time [in years]:  36000.0
# Process layers at time [in years]:  37000.0
# Process layers at time [in years]:  38000.0
# Process layers at time [in years]:  39000.0
# Process layers at time [in years]:  40000.0
# Process layers at time [in years]:  41000.0
# Process layers at time [in years]:  42000.0
# Process layers at time [in years]:  43000.0
# Process layers at time [in years]:  44000.0
# Process layers at time [in years]:  45000.0
# Process layers at time [in years]:  46000.0
# Process layers at time [in years]:  47000.0
# Process layers at time [in years]:  48000.0
# Process layers at time [in years]:  49000.0
# Process layers at time [in years]:  50000.0
# Process layers at time [in years]:  51000.0
# Process layers at time [in years]:  52000.0
# Process layers at time [in years]:  53000.0
# Process layers at time [in years]:  54000.0
# Process layers at time [in years]:  55000.0
#         Model Pur040 stratal_series created
# Done

# %%
for i in models:
    # Initialise model
    #model = badlandsModel()

    # Define the XmL input file
    #model.load_xml('Pur' + str(i).zfill(3) + '.xml')
    
    # Run the model
    #model.run_to_time(runTime)
    
    #print "        Model Pur" + str(i).zfill(3) + " run"
    
    # Initialise the mesh function
    mesh = strati.stratiMesh(folder='Pur' + str(i).zfill(3), xdmfName = 'stratal_series', ncpus=1, layperstep=1, dispTime=1000.)
    
    # Create the stratigraphic mesh for each of the stratigraphic layers
    mesh.outputSteps(startTime=0.,endTime=runTime)
    
    print "        Model Pur" + str(i).zfill(3) + " stratal_series created"
    
print "Done"
# Out:
# Process layers at time [in years]:  0.0
# Process layers at time [in years]:  1000.0
# Process layers at time [in years]:  2000.0
# Process layers at time [in years]:  3000.0
# Process layers at time [in years]:  4000.0
# Process layers at time [in years]:  5000.0
# Process layers at time [in years]:  6000.0
# Process layers at time [in years]:  7000.0
# Process layers at time [in years]:  8000.0
# Process layers at time [in years]:  9000.0
# Process layers at time [in years]:  10000.0
# Process layers at time [in years]:  11000.0
# Process layers at time [in years]:  12000.0
# Process layers at time [in years]:  13000.0
# Process layers at time [in years]:  14000.0
# Process layers at time [in years]:  15000.0
# Process layers at time [in years]:  16000.0
# Process layers at time [in years]:  17000.0
# Process layers at time [in years]:  18000.0
# Process layers at time [in years]:  19000.0
# Process layers at time [in years]:  20000.0
# Process layers at time [in years]:  21000.0
# Process layers at time [in years]:  22000.0
# Process layers at time [in years]:  23000.0
# Process layers at time [in years]:  24000.0
# Process layers at time [in years]:  25000.0
# Process layers at time [in years]:  26000.0
# Process layers at time [in years]:  27000.0
# Process layers at time [in years]:  28000.0
# Process layers at time [in years]:  29000.0
# Process layers at time [in years]:  30000.0
# Process layers at time [in years]:  31000.0
# Process layers at time [in years]:  32000.0
# Process layers at time [in years]:  33000.0
# Process layers at time [in years]:  34000.0
# Process layers at time [in years]:  35000.0
# Process layers at time [in years]:  36000.0
# Process layers at time [in years]:  37000.0
# Process layers at time [in years]:  38000.0
# Process layers at time [in years]:  39000.0
# Process layers at time [in years]:  40000.0
# Process layers at time [in years]:  41000.0
# Process layers at time [in years]:  42000.0
# Process layers at time [in years]:  43000.0
# Process layers at time [in years]:  44000.0
# Process layers at time [in years]:  45000.0
# Process layers at time [in years]:  46000.0
# Process layers at time [in years]:  47000.0
# Process layers at time [in years]:  48000.0
# Process layers at time [in years]:  49000.0
# Process layers at time [in years]:  50000.0
# Process layers at time [in years]:  51000.0
# Process layers at time [in years]:  52000.0
# Process layers at time [in years]:  53000.0
# Process layers at time [in years]:  54000.0
# Process layers at time [in years]:  55000.0
#         Model Pur017 stratal_series created
# Done

# %% [markdown]
# ## Starting pyBadlands
#
# First, we initialise the model and set the path to the **XmL** input file:
#
# + **input.xml**
#
# > You can edit the **XmL** configuration file directly in the _Jupyter environment_ by clicking on it in the `tree` and changing in the **url** the **view** to **edit**.

# %%
from pyBadlands.model import Model as badlandsModel

# Initialise model
model = badlandsModel()

# Define the XmL input file
model.load_xml('VLrun.xml')

# %% [markdown]
# ## Running pyBadlands
#
# We can run the model for a given period. The end time in the **XmL** input file is set to _100 ky_ but you might want to run the model for a coupled of iterations and check the output before running the model for the entire simulation time. This is done by putting the time in the **run_to_time** function.

# %%
model.run_to_time(55000)

# %% [markdown]
# ## Stratigraphic mesh
#
# Once the model has finished you will need to build the stratigraphic mesh. The following cells are used for this purpose... again depending of the size of your model this can be really slow...

# %%
from scripts import stratiMesh as strati

# %% [markdown]
# The stratigraphic mesh will be store in the same folder as your output file (defined in the `XmL` input file) and will be call using the given `xdmfName` (in the example below: `stratal_series`). The newly created xdmf file can be open in `Paraview` like the tin.series and flow.series files...
#
# First we initialise the function:

# %%
mesh = strati.stratiMesh(folder='VL001', xdmfName = 'stratal_series', ncpus=1, layperstep=1, dispTime=1000.)

# %% [markdown]
# Then we create the stratigraphic mesh for each stratigraphic layers:

# %%
#mesh.outputSteps(startTime=0.,endTime=90000.)
mesh.outputSteps(startTime=0.,endTime=55000.)
